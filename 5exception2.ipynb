# %%
#Q1 using the Exception class as the base class for custom exceptions, you ensure compatibility with the language's exception handling mechanisms, facilitate code clarity and maintainability, and leverage language features and tools designed to work with exceptions.

# %%
#Q2 
import inspect
def treeClass(cls, ind = 0):
    print ('-' * ind, cls.__name__)
    for i in cls.__subclasses__():
        treeClass(i, ind + 3)
  
print("Hierarchy for Built-in exceptions is : ")
inspect.getclasstree(inspect.getmro(BaseException))
treeClass(BaseException)
# Out:
# Hierarchy for Built-in exceptions is :
#  BaseException
# --- Exception
# ------ TypeError
# --------- FloatOperation
# --------- MultipartConversionError
# ------ StopAsyncIteration
# ------ StopIteration
# ------ ImportError
# --------- ModuleNotFoundError
# --------- ZipImportError
# ------ OSError
# --------- ConnectionError
# ------------ BrokenPipeError
# ------------ ConnectionAbortedError
# ------------ ConnectionRefusedError
# ------------ ConnectionResetError
# --------------- RemoteDisconnected
# --------- BlockingIOError
# --------- ChildProcessError
# --------- FileExistsError
# --------- FileNotFoundError
# --------- IsADirectoryError
# --------- NotADirectoryError
# --------- InterruptedError
# ------------ InterruptedSystemCall
# --------- PermissionError
# --------- ProcessLookupError
# --------- TimeoutError
# --------- UnsupportedOperation
# --------- itimer_error
# --------- herror
# --------- gaierror
# --------- SSLError
# ------------ SSLCertVerificationError
# ...

# %%
#3 The arithmetic error occurs when an error is encountered during numeric calculations in Python. This includes Zerodivision Error and Floating point error and overflow error. 
# i) zero division error is raised when you divide a numeric value by zero.
5/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 #3 The arithmetic error occurs when an error is encountered during numeric calculations in Python. This includes Zerodivision Error and Floating point error and overflow error.
#       2 #zero division error is raised when you divide a numeric value by zero.
# ----> 3 5/0
#
# ZeroDivisionError: division by zero

# %%
#ii) overflow error this error occurs when an arithmetic operation result is stored in any variable where the result value is larger than any given data type like float, int, etc exceeds the limit or value of current Python runtime values.
a=5
   # for i in range(10000):
    # print( a**i)

# %%
#Q4 LookupError Exception is the Base class for errors raised when something can't be found. The base class for the exceptions that are raised when a key or index used on a mapping or sequence is invalid: IndexError, KeyError.
#Key error:The Python KeyError is raised when a mapping key is not found in the set of existing keys of the mapping
d={"KEY":"Val","valo":"lep"}
print(d["key"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 4
#       1 #Q4 LookupError Exception is the Base class for errors raised when something can't be found. The base class for the exceptions that are raised when a key or index used on a mapping or sequence is invalid: IndexError, KeyError.
#       2 #Key error
#       3 d={"KEY":"Val","valo":"lep"}
# ----> 4 print(d["key"])
#
# KeyError: 'key'

# %%
#Index error:This error occurs when an attempt is made to access an item in a list at an index which is out of bounds
list=[1,2,3,4,5]
print(list[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 3
#       1 #Index error:This error occurs when an attempt is made to access an item in a list at an index which is out of bounds
#       2 list=[1,2,3,4,5]
# ----> 3 print(list[5])
#
# IndexError: list index out of range

# %%
#Q5  ImportError occurs when the Python program tries to import module which does not exist in the private table. 
#The 'module not found' error is a syntax error that appears when the static import statement cannot find the file at the declared path.
import helllooo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 3
#       1 #Q5  ImportError occurs when the Python program tries to import module which does not exist in the private table.
#       2 #The 'module not found' error is a syntax error that appears when the static import statement cannot find the file at the declared path.
# ----> 3 import helllooo
#
# ModuleNotFoundError: No module named 'helllooo'

# %%
#Q6 The best practices for exception handling
#TRY TO USE SPECIFIC ERROR
#PRINT always a proper msg
#Try to use logging
#Always try to use a multiple exception handling
#document all the error
#CLeanup all the resources
